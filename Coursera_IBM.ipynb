# %% [markdown]
# <a href="https://colab.research.google.com/github/SabrinaRoses/Data_Science/blob/main/Coursera_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #My Jupyter Notebook

# %% [markdown]
# Name: **Sabrina Lemes**<br>
# Occupation: I am a student.

# %% [markdown]
# *I am interested in data Sciences because I want to join the field
# of data Analysis.*

# %% [markdown]
# ###My Code will say "Hello" in Python.

# %%
print("Hello There. Thank you!")
# Out:
# Hello There. Thank you!

# %% [markdown]
# #Image:
# ![usar_ibm.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Table:
# <style>
# 	.demo {
# 		border:1px sólido #C0C0C0;
# 		border-collapse:colapso;
# 		padding:5px;
# 	}
# 	.demo th {
# 		border:1px sólido #C0C0C0;
# 		padding:5px;
# 		background:#F0F0F0;
# 	}
# 	.demo td {
# 		border:1px sólido #C0C0C0;
# 		padding:5px;
# 	}
# </style>
# <table class="demo">
# 	<caption>tabela 1</caption>
# 	<thead>
# 	<tr>
# 		<th>Cabeçalho 1</th>
# 		<th>Cabeçalho 2</th>
# 		<th>Cabeçalho 3</th>
# 		<th>Cabeçalho 4</th>
# 	</tr>
# 	</thead>
# 	<tbody>
# 	<tr>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	<tr>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 		<td>&nbsp;</td>
# 	</tr>
# 	</tbody>
# </table>

# %% [markdown]
# #List:
# <html>
# <head>
# <title>List in HTML</title>
# </head>
#
# <body>
# <ol>
# <li>Name</li>
# <li>Contact</li>
# <li>Address</li>
# <li>Country</li>
# </ol>
# </body>
# </html>

# %% [markdown]
# #Note:
# My IBM cloud does not work. That's why I used the collab. Thank You!
